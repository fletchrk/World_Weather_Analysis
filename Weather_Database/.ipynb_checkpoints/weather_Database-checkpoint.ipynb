# %%
# Import dependencies

import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2,000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=1500)
lngs = np.random.uniform(-180.0,180.0,size=1500)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Get the nearest city using citipy module
cities = list()
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient control
print(cities[:10], 'Generate', len(cities))
# Out:
# ['arraial do cabo', 'mys shmidta', 'punta arenas', 'albany', 'busselton', 'bredasdorp', 'camalu', 'mataura', 'panama city', 'cape town'] Generate 621

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | camalu
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | panama city
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | katha
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | kawhia
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | isangel
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | sulangan
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | necochea
# Processing Record 23 of Set 1 | rawah
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | kaduna
# Processing Record 26 of Set 1 | warrnambool
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | mizque
# Processing Record 29 of Set 1 | narsaq
# Processing Record 30 of Set 1 | thaba-tseka
# Processing Record 31 of Set 1 | husavik
# Processing Record 32 of Set 1 | lorengau
# Processing Record 33 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | olafsvik
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | caibarien
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | wadena
# Processing Record 42 of Set 1 | nouadhibou
# Processing Record 43 of Set 1 | maniitsoq
# Processing Record 44 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 1 | grand gaube
# Processing Record 46 of Set 1 | vanavara
# Processing Record 47 of Set 1 | altamira
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | vila velha
# Processing Record 50 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | ketchikan
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | puri
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | kruisfontein
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | honiara
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | sagauli
# Processing Record 11 of Set 2 | astana
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | benjamin constant
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | codrington
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | dindori
# Processing Record 19 of Set 2 | itanhem
# Processing Record 20 of Set 2 | portland
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | baruun-urt
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | mareeba
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | general roca
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | shakawe
# Processing Record 34 of Set 2 | washougal
# Processing Record 35 of Set 2 | wenling
# Processing Record 36 of Set 2 | vestmannaeyjar
# Processing Record 37 of Set 2 | labuhan
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | bilma
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | norman wells
# Processing Record 47 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | namwala
# Processing Record 1 of Set 3 | arcata
# Processing Record 2 of Set 3 | jalu
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | hongjiang
# Processing Record 5 of Set 3 | shiyan
# Processing Record 6 of Set 3 | noshiro
# Processing Record 7 of Set 3 | kemijarvi
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 3 | verkhnyaya inta
# Processing Record 11 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 3 | neiafu
# Processing Record 13 of Set 3 | nacala
# Processing Record 14 of Set 3 | lerwick
# Processing Record 15 of Set 3 | trofors
# Processing Record 16 of Set 3 | moranbah
# Processing Record 17 of Set 3 | mamallapuram
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | saint-augustin
# Processing Record 20 of Set 3 | ambilobe
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | christchurch
# Processing Record 23 of Set 3 | ishigaki
# Processing Record 24 of Set 3 | mwense
# Processing Record 25 of Set 3 | hambantota
# Processing Record 26 of Set 3 | shenjiamen
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | barcelos
# Processing Record 29 of Set 3 | kaili
# Processing Record 30 of Set 3 | severodvinsk
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | lucapa
# Processing Record 33 of Set 3 | ilanskiy
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | komsomolskiy
# Processing Record 37 of Set 3 | ust-tsilma
# Processing Record 38 of Set 3 | nanortalik
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | antalya
# Processing Record 41 of Set 3 | khatanga
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | buala
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | sorland
# Processing Record 47 of Set 3 | abu samrah
# Processing Record 48 of Set 3 | sakakah
# Processing Record 49 of Set 3 | marsabit
# Processing Record 50 of Set 3 | slave lake
# Processing Record 1 of Set 4 | santiago del estero
# Processing Record 2 of Set 4 | honningsvag
# Processing Record 3 of Set 4 | shimoda
# Processing Record 4 of Set 4 | carutapera
# Processing Record 5 of Set 4 | ciudad real
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | lukuledi
# Processing Record 8 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 4 | ipora
# Processing Record 10 of Set 4 | sinjah
# City not found. Skipping...
# Processing Record 11 of Set 4 | yala
# Processing Record 12 of Set 4 | yerbogachen
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | santa maria
# Processing Record 15 of Set 4 | mehamn
# Processing Record 16 of Set 4 | manokwari
# Processing Record 17 of Set 4 | boguchany
# Processing Record 18 of Set 4 | coquimbo
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | giyani
# Processing Record 22 of Set 4 | riyadh
# Processing Record 23 of Set 4 | alofi
# Processing Record 24 of Set 4 | trincomalee
# Processing Record 25 of Set 4 | teya
# Processing Record 26 of Set 4 | tchibanga
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | araouane
# Processing Record 29 of Set 4 | axim
# Processing Record 30 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 4 | muros
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | zhangjiakou
# Processing Record 34 of Set 4 | lodja
# Processing Record 35 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 4 | kant
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | verkh-usugli
# Processing Record 39 of Set 4 | ugoofaaru
# Processing Record 40 of Set 4 | ipixuna
# Processing Record 41 of Set 4 | san cristobal
# Processing Record 42 of Set 4 | sovetskiy
# Processing Record 43 of Set 4 | shenzhen
# Processing Record 44 of Set 4 | kaitangata
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | kapit
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | poum
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 5 | elmira
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | ostrovnoy
# Processing Record 4 of Set 5 | raudeberg
# Processing Record 5 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 5 | vigrestad
# Processing Record 7 of Set 5 | moron
# Processing Record 8 of Set 5 | bambous virieux
# Processing Record 9 of Set 5 | cherskiy
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | fortuna
# Processing Record 12 of Set 5 | cockburn town
# Processing Record 13 of Set 5 | narrabri
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | praia da vitoria
# Processing Record 16 of Set 5 | manaure
# Processing Record 17 of Set 5 | havre-saint-pierre
# Processing Record 18 of Set 5 | ubon ratchathani
# Processing Record 19 of Set 5 | bulgan
# Processing Record 20 of Set 5 | jiblah
# Processing Record 21 of Set 5 | tubuala
# Processing Record 22 of Set 5 | atar
# Processing Record 23 of Set 5 | the pas
# Processing Record 24 of Set 5 | watford
# Processing Record 25 of Set 5 | manggar
# Processing Record 26 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 27 of Set 5 | zdunska wola
# Processing Record 28 of Set 5 | melbu
# Processing Record 29 of Set 5 | marienburg
# Processing Record 30 of Set 5 | chuy
# Processing Record 31 of Set 5 | ribeira brava
# Processing Record 32 of Set 5 | capitan bado
# Processing Record 33 of Set 5 | khokhlovo
# Processing Record 34 of Set 5 | synya
# Processing Record 35 of Set 5 | poopo
# Processing Record 36 of Set 5 | sechura
# Processing Record 37 of Set 5 | prievidza
# Processing Record 38 of Set 5 | margate
# Processing Record 39 of Set 5 | alyangula
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | aklavik
# Processing Record 42 of Set 5 | tagusao
# Processing Record 43 of Set 5 | jati
# Processing Record 44 of Set 5 | yulara
# Processing Record 45 of Set 5 | pontes e lacerda
# Processing Record 46 of Set 5 | ponta do sol
# Processing Record 47 of Set 5 | baykit
# Processing Record 48 of Set 5 | zeya
# Processing Record 49 of Set 5 | iqaluit
# Processing Record 50 of Set 5 | broken hill
# Processing Record 1 of Set 6 | gander
# Processing Record 2 of Set 6 | port keats
# Processing Record 3 of Set 6 | fairbanks
# Processing Record 4 of Set 6 | quatre cocos
# Processing Record 5 of Set 6 | rebricea
# Processing Record 6 of Set 6 | ballina
# Processing Record 7 of Set 6 | shorewood
# Processing Record 8 of Set 6 | northam
# Processing Record 9 of Set 6 | kaeo
# Processing Record 10 of Set 6 | kalabo
# Processing Record 11 of Set 6 | luderitz
# Processing Record 12 of Set 6 | ayr
# Processing Record 13 of Set 6 | bathsheba
# Processing Record 14 of Set 6 | raga
# Processing Record 15 of Set 6 | nyaunglebin
# Processing Record 16 of Set 6 | cangzhou
# Processing Record 17 of Set 6 | port blair
# Processing Record 18 of Set 6 | huarmey
# Processing Record 19 of Set 6 | qui nhon
# Processing Record 20 of Set 6 | nanyamba
# Processing Record 21 of Set 6 | grafton
# Processing Record 22 of Set 6 | bismarck
# Processing Record 23 of Set 6 | cabimas
# Processing Record 24 of Set 6 | lons-le-saunier
# Processing Record 25 of Set 6 | broome
# Processing Record 26 of Set 6 | lata
# Processing Record 27 of Set 6 | rawson
# Processing Record 28 of Set 6 | moose factory
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | rangpo
# Processing Record 31 of Set 6 | calvinia
# Processing Record 32 of Set 6 | tateyama
# Processing Record 33 of Set 6 | khandagayty
# Processing Record 34 of Set 6 | constitucion
# Processing Record 35 of Set 6 | tocopilla
# Processing Record 36 of Set 6 | nuuk
# Processing Record 37 of Set 6 | kushima
# Processing Record 38 of Set 6 | calarasi
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | port washington
# Processing Record 41 of Set 6 | tucuman
# Processing Record 42 of Set 6 | aguimes
# Processing Record 43 of Set 6 | arica
# Processing Record 44 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | springbok
# Processing Record 49 of Set 6 | progreso
# Processing Record 50 of Set 6 | marzuq
# Processing Record 1 of Set 7 | tanshui
# City not found. Skipping...
# Processing Record 2 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 7 | alexandria
# Processing Record 4 of Set 7 | marathon
# Processing Record 5 of Set 7 | tura
# Processing Record 6 of Set 7 | prince rupert
# Processing Record 7 of Set 7 | grindavik
# Processing Record 8 of Set 7 | portree
# Processing Record 9 of Set 7 | tautira
# Processing Record 10 of Set 7 | ahipara
# Processing Record 11 of Set 7 | sinnamary
# Processing Record 12 of Set 7 | jibuti
# Processing Record 13 of Set 7 | buchanan
# Processing Record 14 of Set 7 | peace river
# Processing Record 15 of Set 7 | evensk
# Processing Record 16 of Set 7 | mantua
# Processing Record 17 of Set 7 | batticaloa
# Processing Record 18 of Set 7 | puerto escondido
# Processing Record 19 of Set 7 | saint-georges
# Processing Record 20 of Set 7 | yeppoon
# Processing Record 21 of Set 7 | kencong
# Processing Record 22 of Set 7 | leningradskiy
# Processing Record 23 of Set 7 | meulaboh
# Processing Record 24 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 25 of Set 7 | malanje
# Processing Record 26 of Set 7 | sabang
# Processing Record 27 of Set 7 | ulladulla
# Processing Record 28 of Set 7 | zhoucheng
# Processing Record 29 of Set 7 | penon blanco
# Processing Record 30 of Set 7 | fairfield
# Processing Record 31 of Set 7 | lobva
# Processing Record 32 of Set 7 | krasnoselkup
# Processing Record 33 of Set 7 | yangmei
# Processing Record 34 of Set 7 | fengzhen
# Processing Record 35 of Set 7 | lumphat
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | matagami
# Processing Record 39 of Set 7 | cooma
# Processing Record 40 of Set 7 | barra patuca
# Processing Record 41 of Set 7 | port hawkesbury
# Processing Record 42 of Set 7 | bubaque
# Processing Record 43 of Set 7 | kuryk
# Processing Record 44 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 7 | chengzihe
# Processing Record 46 of Set 7 | souillac
# Processing Record 47 of Set 7 | joshimath
# Processing Record 48 of Set 7 | namibe
# Processing Record 49 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 50 of Set 7 | mount gambier
# Processing Record 1 of Set 8 | council bluffs
# Processing Record 2 of Set 8 | ocho rios
# Processing Record 3 of Set 8 | mount isa
# Processing Record 4 of Set 8 | bengkulu
# Processing Record 5 of Set 8 | cheremnoye
# Processing Record 6 of Set 8 | garowe
# Processing Record 7 of Set 8 | kavaratti
# Processing Record 8 of Set 8 | zhezkazgan
# Processing Record 9 of Set 8 | chipaque
# Processing Record 10 of Set 8 | mozarlandia
# Processing Record 11 of Set 8 | dingle
# Processing Record 12 of Set 8 | rio gallegos
# Processing Record 13 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 8 | gravdal
# Processing Record 15 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 8 | srednekolymsk
# Processing Record 17 of Set 8 | alekseyevskoye
# Processing Record 18 of Set 8 | bone
# Processing Record 19 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 8 | metu
# Processing Record 21 of Set 8 | flinders
# Processing Record 22 of Set 8 | brae
# Processing Record 23 of Set 8 | touros
# Processing Record 24 of Set 8 | monteagudo
# Processing Record 25 of Set 8 | bytosh
# Processing Record 26 of Set 8 | richards bay
# Processing Record 27 of Set 8 | batsfjord
# Processing Record 28 of Set 8 | naryan-mar
# Processing Record 29 of Set 8 | caravelas
# Processing Record 30 of Set 8 | aripuana
# Processing Record 31 of Set 8 | tutoia
# Processing Record 32 of Set 8 | avera
# Processing Record 33 of Set 8 | akdepe
# Processing Record 34 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 8 | salalah
# Processing Record 36 of Set 8 | vostok
# Processing Record 37 of Set 8 | beyneu
# Processing Record 38 of Set 8 | calabozo
# Processing Record 39 of Set 8 | nome
# Processing Record 40 of Set 8 | el paso
# Processing Record 41 of Set 8 | yumen
# Processing Record 42 of Set 8 | labrea
# Processing Record 43 of Set 8 | gorontalo
# Processing Record 44 of Set 8 | acarau
# Processing Record 45 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 46 of Set 8 | colares
# Processing Record 47 of Set 8 | thompson
# Processing Record 48 of Set 8 | acapulco
# Processing Record 49 of Set 8 | krasnoye
# Processing Record 50 of Set 8 | onega
# Processing Record 1 of Set 9 | lewisville
# Processing Record 2 of Set 9 | ambon
# Processing Record 3 of Set 9 | camabatela
# Processing Record 4 of Set 9 | gornopravdinsk
# Processing Record 5 of Set 9 | peniche
# Processing Record 6 of Set 9 | coos bay
# Processing Record 7 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 9 | maragogi
# Processing Record 9 of Set 9 | berlevag
# Processing Record 10 of Set 9 | ilulissat
# Processing Record 11 of Set 9 | bien hoa
# Processing Record 12 of Set 9 | college
# Processing Record 13 of Set 9 | ginda
# Processing Record 14 of Set 9 | praia
# Processing Record 15 of Set 9 | vao
# Processing Record 16 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 9 | lebu
# Processing Record 18 of Set 9 | mawlaik
# Processing Record 19 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 9 | stromness
# Processing Record 21 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 9 | callaguip
# Processing Record 23 of Set 9 | cayenne
# Processing Record 24 of Set 9 | worland
# Processing Record 25 of Set 9 | beringovskiy
# Processing Record 26 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 9 | victor harbor
# Processing Record 29 of Set 9 | khandyga
# Processing Record 30 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 9 | marsa matruh
# Processing Record 32 of Set 9 | mazamitla
# Processing Record 33 of Set 9 | turukhansk
# Processing Record 34 of Set 9 | umm lajj
# Processing Record 35 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 36 of Set 9 | bonavista
# Processing Record 37 of Set 9 | oksfjord
# Processing Record 38 of Set 9 | dera ghazi khan
# Processing Record 39 of Set 9 | solnechnyy
# Processing Record 40 of Set 9 | manicore
# Processing Record 41 of Set 9 | iracoubo
# Processing Record 42 of Set 9 | mahon
# Processing Record 43 of Set 9 | sao joao da barra
# Processing Record 44 of Set 9 | san patricio
# Processing Record 45 of Set 9 | north bend
# Processing Record 46 of Set 9 | kahului
# Processing Record 47 of Set 9 | boca do acre
# Processing Record 48 of Set 9 | pontarlier
# Processing Record 49 of Set 9 | mala vyska
# Processing Record 50 of Set 9 | salisbury
# Processing Record 1 of Set 10 | ashtian
# Processing Record 2 of Set 10 | port lincoln
# Processing Record 3 of Set 10 | bailleul
# Processing Record 4 of Set 10 | poddorye
# Processing Record 5 of Set 10 | boende
# Processing Record 6 of Set 10 | katangli
# Processing Record 7 of Set 10 | tuensang
# Processing Record 8 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 10 | mancio lima
# Processing Record 10 of Set 10 | didwana
# Processing Record 11 of Set 10 | gorodets
# Processing Record 12 of Set 10 | corinto
# Processing Record 13 of Set 10 | sambava
# Processing Record 14 of Set 10 | shuyskoye
# Processing Record 15 of Set 10 | mishan
# Processing Record 16 of Set 10 | morros
# Processing Record 17 of Set 10 | predivinsk
# Processing Record 18 of Set 10 | tanout
# Processing Record 19 of Set 10 | pililla
# Processing Record 20 of Set 10 | morvi
# Processing Record 21 of Set 10 | tahoua
# Processing Record 22 of Set 10 | natal
# Processing Record 23 of Set 10 | sola
# Processing Record 24 of Set 10 | palmer
# Processing Record 25 of Set 10 | bandarbeyla
# Processing Record 26 of Set 10 | jacksonville
# Processing Record 27 of Set 10 | launceston
# Processing Record 28 of Set 10 | ayan
# Processing Record 29 of Set 10 | tuatapere
# Processing Record 30 of Set 10 | valdepenas
# Processing Record 31 of Set 10 | opuwo
# Processing Record 32 of Set 10 | herat
# Processing Record 33 of Set 10 | tiznit
# Processing Record 34 of Set 10 | padang
# Processing Record 35 of Set 10 | puebla
# Processing Record 36 of Set 10 | koutsouras
# Processing Record 37 of Set 10 | katobu
# Processing Record 38 of Set 10 | svetlogorsk
# Processing Record 39 of Set 10 | nuoro
# Processing Record 40 of Set 10 | kavieng
# Processing Record 41 of Set 10 | banjar
# Processing Record 42 of Set 10 | west bay
# Processing Record 43 of Set 10 | hay river
# Processing Record 44 of Set 10 | lovozero
# Processing Record 45 of Set 10 | french harbor
# Processing Record 46 of Set 10 | qasigiannguit
# Processing Record 47 of Set 10 | kempen
# Processing Record 48 of Set 10 | saint-pierre
# Processing Record 49 of Set 10 | lalsk
# Processing Record 50 of Set 10 | anjiang
# Processing Record 1 of Set 11 | muyezerskiy
# Processing Record 2 of Set 11 | nanakuli
# Processing Record 3 of Set 11 | vanimo
# Processing Record 4 of Set 11 | campobello di mazara
# Processing Record 5 of Set 11 | ushumun
# Processing Record 6 of Set 11 | hami
# Processing Record 7 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 11 | itarema
# Processing Record 9 of Set 11 | vung tau
# Processing Record 10 of Set 11 | masumbwe
# Processing Record 11 of Set 11 | zhigansk
# Processing Record 12 of Set 11 | marawi
# Processing Record 13 of Set 11 | oleksandrivka
# Processing Record 14 of Set 11 | cordoba
# Processing Record 15 of Set 11 | wajima
# Processing Record 16 of Set 11 | benha
# City not found. Skipping...
# Processing Record 17 of Set 11 | benghazi
# Processing Record 18 of Set 11 | esperance
# Processing Record 19 of Set 11 | kununurra
# Processing Record 20 of Set 11 | comodoro rivadavia
# Processing Record 21 of Set 11 | siniscola
# Processing Record 22 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 23 of Set 11 | san pedro
# Processing Record 24 of Set 11 | karratha
# Processing Record 25 of Set 11 | puerto rondon
# Processing Record 26 of Set 11 | chiredzi
# Processing Record 27 of Set 11 | guder
# Processing Record 28 of Set 11 | catalina foothills
# Processing Record 29 of Set 11 | harper
# Processing Record 30 of Set 11 | vila franca do campo
# Processing Record 31 of Set 11 | leua
# Processing Record 32 of Set 11 | hofn
# Processing Record 33 of Set 11 | sertanopolis
# Processing Record 34 of Set 11 | verkhnevilyuysk
# Processing Record 35 of Set 11 | kidal
# Processing Record 36 of Set 11 | knokke-heist
# Processing Record 37 of Set 11 | ouegoa
# Processing Record 38 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 11 | zheleznodorozhnyy
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | langsa
# Processing Record 42 of Set 11 | puerto leguizamo
# Processing Record 43 of Set 11 | talnakh
# Processing Record 44 of Set 11 | maceio
# Processing Record 45 of Set 11 | pisco
# Processing Record 46 of Set 11 | prado
# Processing Record 47 of Set 11 | kuching
# Processing Record 48 of Set 11 | agboville
# Processing Record 49 of Set 11 | tadine
# Processing Record 50 of Set 11 | kysyl-syr
# Processing Record 1 of Set 12 | samarai
# Processing Record 2 of Set 12 | warri
# Processing Record 3 of Set 12 | san quintin
# Processing Record 4 of Set 12 | khrebtovaya
# Processing Record 5 of Set 12 | dongying
# Processing Record 6 of Set 12 | praxedis guerrero
# Processing Record 7 of Set 12 | korla
# Processing Record 8 of Set 12 | talcahuano
# Processing Record 9 of Set 12 | armeria
# Processing Record 10 of Set 12 | ingham
# Processing Record 11 of Set 12 | camacha
# Processing Record 12 of Set 12 | banda aceh
# Processing Record 13 of Set 12 | natchez
# Processing Record 14 of Set 12 | kirovsk
# Processing Record 15 of Set 12 | tiarei
# Processing Record 16 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 17 of Set 12 | sokoni
# Processing Record 18 of Set 12 | sur
# Processing Record 19 of Set 12 | orlik
# Processing Record 20 of Set 12 | kaseda
# Processing Record 21 of Set 12 | la paz
# Processing Record 22 of Set 12 | lebedinyy
# Processing Record 23 of Set 12 | benguela
# Processing Record 24 of Set 12 | hervey bay
# Processing Record 25 of Set 12 | rudnya
# Processing Record 26 of Set 12 | vardo
# Processing Record 27 of Set 12 | kajaani
# Processing Record 28 of Set 12 | sheregesh
# Processing Record 29 of Set 12 | lasa
# Processing Record 30 of Set 12 | dzheguta
# Processing Record 31 of Set 12 | gat
# Processing Record 32 of Set 12 | dano
# Processing Record 33 of Set 12 | trinidad
# Processing Record 34 of Set 12 | rocha
# Processing Record 35 of Set 12 | mhango
# Processing Record 36 of Set 12 | fengkou
# Processing Record 37 of Set 12 | marica
# Processing Record 38 of Set 12 | laguna
# Processing Record 39 of Set 12 | tubig indangan
# City not found. Skipping...
# Processing Record 40 of Set 12 | potosi
# Processing Record 41 of Set 12 | luwuk
# Processing Record 42 of Set 12 | pengcheng
# Processing Record 43 of Set 12 | henties bay
# Processing Record 44 of Set 12 | uthal
# Processing Record 45 of Set 12 | mazulskiy
# City not found. Skipping...
# Processing Record 46 of Set 12 | ilo
# Processing Record 47 of Set 12 | nyurba
# Processing Record 48 of Set 12 | kathu
# Processing Record 49 of Set 12 | sabha
# Processing Record 50 of Set 12 | chumikan
# Processing Record 1 of Set 13 | arlit
# Processing Record 2 of Set 13 | yuci
# Processing Record 3 of Set 13 | tres palos
# Processing Record 4 of Set 13 | kazanka
# Processing Record 5 of Set 13 | maymanak
# City not found. Skipping...
# Processing Record 6 of Set 13 | tessalit
# Processing Record 7 of Set 13 | barreirinha
# Processing Record 8 of Set 13 | medicine hat
# Processing Record 9 of Set 13 | sosnovo-ozerskoye
# Processing Record 10 of Set 13 | liverpool
# Processing Record 11 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 13 | bonthe
# Processing Record 13 of Set 13 | mitake
# Processing Record 14 of Set 13 | la asuncion
# Processing Record 15 of Set 13 | tigil
# Processing Record 16 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 17 of Set 13 | half moon bay
# Processing Record 18 of Set 13 | labuan
# Processing Record 19 of Set 13 | mokhsogollokh
# Processing Record 20 of Set 13 | wattegama
# Processing Record 21 of Set 13 | gurh
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 569

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
WeatherPy_Database_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
WeatherPy_Database_df = WeatherPy_Database_df[new_column_order]
WeatherPy_Database_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  arraial do cabo      BR -22.9661  -42.0278     75.97        87         100
# 1     punta arenas      CL -53.1500  -70.9167     44.01        65           0
# 2           albany      US  42.6001  -73.9662     33.01        51           1
# 3        busselton      AU -33.6500  115.3333     72.00        48           0
# 4       bredasdorp      ZA -34.5322   20.0403     64.40        82          97
# 5           camalu      MX  30.8500 -116.0667     50.00        61          13
# 6          mataura      NZ -46.1927  168.8643     73.00        44          28
# 7      panama city      PA   8.9936  -79.5197     77.00        78          90
# 8        cape town      ZA -33.9258   18.4232     66.20        72          75
# 9          rikitea      PF -23.1203 -134.9692     80.29        74          29
#
#    Wind Speed Current Description
# 0       14.09     overcast clouds
# 1        3.44           clear sky
# 2        5.14           clear sky
# 3        5.01           clear sky
# 4        3.44     overcast clouds
# 5        1.01          few clouds
# 6       18.99    scattered clouds
# 7        6.91     overcast clouds
# 8       10.36       broken clouds
# 9        9.01    scattered clouds

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# 8b. Export the City_Data into a csv
WeatherPy_Database_df.to_csv(output_data_file, index_label="City_ID")
